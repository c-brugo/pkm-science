# %% [markdown]
# <a href="https://colab.research.google.com/github/c-brugo/pkm-science/blob/main/statsugiri.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#####  Filtra per Pokemon  #####
pokemon = {
  "pkmn":  "arcanine",
  "pkmn2": "flutter mane",
  "pkmn3": "ting-lu",
  "pkmn4": "",
  "pkmn5": "",
  "pkmn6": ""
}

################################


import requests
import pandas as pd
from google.colab import data_table

params = {k: v for k, v in pokemon.items() if v}
response = requests.get("https://api.statsugiri.gg/teams/gen9vgc2023regulationc/today", params=params)
response = response.json()
print("# team: {}".format(response["num_teams"]))
print(response["snapshot_date"])
teams = []
for team in response["teams"]:
  teams.append({
      "Rating": team["rating"],
      "Pokemon 1": team["pkmn_team"][0],
      "Pokemon 2": team["pkmn_team"][1],
      "Pokemon 3": team["pkmn_team"][2],
      "Pokemon 4": team["pkmn_team"][3],
      "Pokemon 5": team["pkmn_team"][4],
      "Pokemon 6": team["pkmn_team"][5],
      "Replay date": team["replay_upload_date"],
      "Replay": "https://replay.pokemonshowdown.com/" + team["replay_id"]
  })


data_table.DataTable(pd.DataFrame(teams), include_index=False, num_rows_per_page=20)
# Out:
# # team: 7
# 2023-04-19
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Rating</th>
#       <th>Pokemon 1</th>
#       <th>Pokemon 2</th>
#       <th>Pokemon 3</th>
#       <th>Pokemon 4</th>
#       <th>Pokemon 5</th>
#       <th>Pokemon 6</th>
#       <th>Replay date</th>
#       <th>Replay</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1764</td>
#       <td>amoonguss</td>
#       <td>arcanine</td>
#       <td>baxcalibur</td>
#       <td>flutter mane</td>
#       <td>palafin</td>
#       <td>ting-lu</td>
#       <td>2023-04-16</td>
#       <td>https://replay.pokemonshowdown.com/gen9vgc2023...</td>
#     </tr>
#     <tr>
# ...
