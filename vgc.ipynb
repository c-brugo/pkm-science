# %% [markdown]
# <a href="https://colab.research.google.com/github/c-brugo/pkm-science/blob/main/vgc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
from google.colab import data_table

response = requests.get("https://api.statsugiri.gg/teams/gen9vgc2023regulationc/today")
response = response.json()
print("# team: {}".format(response["num_teams"]))
print(response["snapshot_date"])
teams = []
for team in response["teams"]:
  teams.append({
      "Rating": team["rating"],
      "Pokemon 1": team["pkmn_team"][0],
      "Pokemon 2": team["pkmn_team"][1],
      "Pokemon 3": team["pkmn_team"][2],
      "Pokemon 4": team["pkmn_team"][3],
      "Pokemon 5": team["pkmn_team"][4],
      "Pokemon 6": team["pkmn_team"][5],
      "Replay date": team["replay_upload_date"],
      "Replay": "https://replay.pokemonshowdown.com/" + team["replay_id"]
  })


data_table.DataTable(pd.DataFrame(teams), include_index=False, num_rows_per_page=20)
# Out:
# # team: 94
# 2023-04-19
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Rating</th>
#       <th>Pokemon 1</th>
#       <th>Pokemon 2</th>
#       <th>Pokemon 3</th>
#       <th>Pokemon 4</th>
#       <th>Pokemon 5</th>
#       <th>Pokemon 6</th>
#       <th>Replay date</th>
#       <th>Replay</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1849</td>
#       <td>chi-yu</td>
#       <td>dondozo</td>
#       <td>dragonite</td>
#       <td>flutter mane</td>
#       <td>glimmora</td>
#       <td>tatsugiri</td>
#       <td>2023-04-16</td>
#       <td>https://replay.pokemonshowdown.com/gen9vgc2023...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1848</td>
#       <td>annihilape</td>
#       <td>chien-pao</td>
#       <td>farigiraf</td>
#       <td>flutter mane</td>
#       <td>lycanroc</td>
#       <td>tyranitar</td>
#       <td>2023-04-15</td>
#       <td>https://replay.pokemonshowdown.com/gen9vgc2023...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1828</td>
#       <td>chien-pao</td>
#       <td>dragonite</td>
#       <td>flutter mane</td>
#       <td>garchomp</td>
#       <td>iron bundle</td>
#       <td>kingambit</td>
#       <td>2023-04-05</td>
#       <td>https://replay.pokemonshowdown.com/gen9vgc2023...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1813</td>
#       <td>amoonguss</td>
#       <td>arcanine</td>
#       <td>chien-pao</td>
#       <td>dragonite</td>
#       <td>flutter mane</td>
#       <td>kingambit</td>
#       <td>2023-04-06</td>
#       <td>https://replay.pokemonshowdown.com/gen9vgc2023...</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1811</td>
#       <td>annihilape</td>
#       <td>blissey</td>
#       <td>farigiraf</td>
#       <td>iron hands</td>
#       <td>staraptor</td>
#       <td>sylveon</td>
#       <td>2023-04-01</td>
#       <td>https://replay.pokemonshowdown.com/gen9vgc2023...</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>89</th>
#       <td>1646</td>
#       <td>amoonguss</td>
#       <td>arcanine</td>
#       <td>corviknight</td>
#       <td>flutter mane</td>
#       <td>palafin</td>
#       <td>ting-lu</td>
#       <td>2023-04-08</td>
#       <td>https://replay.pokemonshowdown.com/gen9vgc2023...</td>
#     </tr>
#     <tr>
#       <th>90</th>
#       <td>1646</td>
#       <td>chi-yu</td>
#       <td>chien-pao</td>
#       <td>dondozo</td>
#       <td>dragonite</td>
#       <td>flutter mane</td>
#       <td>tatsugiri</td>
#       <td>2023-04-12</td>
#       <td>https://replay.pokemonshowdown.com/gen9vgc2023...</td>
#     </tr>
#     <tr>
#       <th>91</th>
#       <td>1645</td>
#       <td>annihilape</td>
#       <td>chi-yu</td>
#       <td>iron bundle</td>
#       <td>maushold</td>
#       <td>scizor</td>
#       <td>wo-chien</td>
#       <td>2023-03-30</td>
#       <td>https://replay.pokemonshowdown.com/gen9vgc2023...</td>
#     </tr>
#     <tr>
#       <th>92</th>
#       <td>1645</td>
#       <td>annihilape</td>
#       <td>chi-yu</td>
#       <td>flutter mane</td>
#       <td>indeedee-f</td>
#       <td>torkoal</td>
#       <td>tyranitar</td>
#       <td>2023-03-30</td>
#       <td>https://replay.pokemonshowdown.com/gen9vgc2023...</td>
#     </tr>
#     <tr>
#       <th>93</th>
#       <td>1644</td>
#       <td>amoonguss</td>
#       <td>annihilape</td>
#       <td>bronzong</td>
#       <td>iron hands</td>
#       <td>kingambit</td>
#       <td>ting-lu</td>
#       <td>2023-04-17</td>
#       <td>https://replay.pokemonshowdown.com/gen9vgc2023...</td>
#     </tr>
#   </tbody>
# </table>
# <p>94 rows × 9 columns</p>
# </div>
